# %%
from nltk.book import*

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
sorted([w for w in set(text1) if w.endswith('ableness')])
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted([term for term in set(text4) if 'gnt' in term])
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted([item for item in set(text5)])
# Out:
# ['',
#  '!',
#  '!!',
#  '!!!',
#  '!!!!',
#  '!!!!!',
#  '!!!!!!',
#  '!!!!!!!',
#  '!!!!!!!!',
#  '!!!!!!!!!',
#  '!!!!!!!!!!',
#  '!!!!!!!!!!!',
#  '!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!.',
#  '!!!!!.',
#  '!!!!....',
#  '!!!.',
#  '!!.',
#  '!!...',
#  '!.',
#  '!...',
#  '!=',
#  '!?',
#  '!??',
#  '!???',
#  '"',
#  '"...',
#  '"?',
#  '"s',
#  '#',
#  '###',
#  '####',
#  '#14-19teens',
#  '#40sPlus',
#  '#prideIsland',
#  '#prideisland',
#  '#talkcity-20s',
#  '#talkcity_adults',
#  '$',
#  '$$',
#  '$27',
#  '&',
#  '&^',
#  "'",
#  "''",
#  "'.",
#  "'d",
#  "'ello",
#  "'ll",
#  "'m",
#  "'n'",
#  "'re",
#  "'s",
#  "'ve",
#  '(',
#  '( o Y o )',
#  '(((',
#  '((((',
#  '(((((',
#  '((((((',
#  '(((((((',
#  '((((((((',
#  '(((((((((',
#  '((((((((((',
#  '(((((((((((',
# ...

# %%
sent1=['call','me','Ishmael','.']
for xyz in sent1:
    if xyz.endswith('I'):
       print(xyz)

# %%
    #Gutenberg corpus
